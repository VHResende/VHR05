# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Código:

url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.status_code #ok para a API
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items']) #trazendo o arquivo para consulta (lista de dicionários)
# Out:
# [{'id_pleito': 7080, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000492/2012-28', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 300000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '03/09/2012'}, {'id_pleito': 8556, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000797/2010-78', 'data_protocolo': '2011-06-30T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'M
# ...

# %%
dados_PVL_RJ = pd.DataFrame(data_json['items']) #visualisando num DataFrame
dados_PVL_RJ
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        7080           Estado  Rio de Janeiro        33  RJ
# 1        8556           Estado  Rio de Janeiro        33  RJ
# 2       10002           Estado  Rio de Janeiro        33  RJ
# 3        9750           Estado  Rio de Janeiro        33  RJ
# 4       10673           Estado  Rio de Janeiro        33  RJ
# 5       21388           Estado  Rio de Janeiro        33  RJ
# 6       11306           Estado  Rio de Janeiro        33  RJ
# 7       13624           Estado  Rio de Janeiro        33  RJ
# 8        7085           Estado  Rio de Janeiro        33  RJ
# 9        5516           Estado  Rio de Janeiro        33  RJ
# 10       7525           Estado  Rio de Janeiro        33  RJ
# 11       5943           Estado  Rio de Janeiro        33  RJ
# 12      12018           Estado  Rio de Janeiro        33  RJ
# 13      10561           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Código:

dados_PVL_RJ['status'].unique()#retornando quais status nós temos neste DataFrame
# Out:
# array(['Encaminhado à PGFN com manifestação técnica favorável',
#        'Deferido', 'Arquivado a pedido', 'Arquivado por decurso de prazo'],
#       dtype=object)

# %%
dados_PVL_RJ['status'].nunique() #retornando o número total de status neste DataFrame
# Out:
# 4

# %%
dados_PVL_RJ.status #visualizando dados
# Out:
# 0     Encaminhado à PGFN com manifestação técnica fa...
# 1     Encaminhado à PGFN com manifestação técnica fa...
# 2     Encaminhado à PGFN com manifestação técnica fa...
# 3                                              Deferido
# 4     Encaminhado à PGFN com manifestação técnica fa...
# 5     Encaminhado à PGFN com manifestação técnica fa...
# 6     Encaminhado à PGFN com manifestação técnica fa...
# 7                                              Deferido
# 8     Encaminhado à PGFN com manifestação técnica fa...
# 9     Encaminhado à PGFN com manifestação técnica fa...
# 10                                             Deferido
# 11    Encaminhado à PGFN com manifestação técnica fa...
# 12    Encaminhado à PGFN com manifestação técnica fa...
# 13    Encaminhado à PGFN com manifestação técnica fa...
# 14    Encaminhado à PGFN com manifestação técnica fa...
# 15    Encaminhado à PGFN com manifestação técnica fa...
# 16                                             Deferido
# ...

# %%
#Visualizando cada status no Dataframe: 

dados_PVL_RJ.loc[dados_PVL_RJ['status'] == 'Encaminhado à PGFN com manifestação técnica favorável']
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        7080           Estado  Rio de Janeiro        33  RJ
# 1        8556           Estado  Rio de Janeiro        33  RJ
# 2       10002           Estado  Rio de Janeiro        33  RJ
# 4       10673           Estado  Rio de Janeiro        33  RJ
# 5       21388           Estado  Rio de Janeiro        33  RJ
# 6       11306           Estado  Rio de Janeiro        33  RJ
# 8        7085           Estado  Rio de Janeiro        33  RJ
# 9        5516           Estado  Rio de Janeiro        33  RJ
# 11       5943           Estado  Rio de Janeiro        33  RJ
# 12      12018           Estado  Rio de Janeiro        33  RJ
# 13      10561           Estado  Rio de Janeiro        33  RJ
# 14      10562           Estado  Rio de Janeiro        33  RJ
# 15      12375           Estado  Rio de Janeiro        33  RJ
# 17      13364           Estado  Rio de Janeiro        33  RJ
# ...

# %%
dados_PVL_RJ.loc[dados_PVL_RJ['status'] == 'Deferido']
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 3        9750           Estado  Rio de Janeiro        33  RJ    None
# 7       13624           Estado  Rio de Janeiro        33  RJ    None
# 10       7525           Estado  Rio de Janeiro        33  RJ    None
# 16      13560           Estado  Rio de Janeiro        33  RJ    None
# 21       6660           Estado  Rio de Janeiro        33  RJ    None
# 30       4997           Estado  Rio de Janeiro        33  RJ    None
# 31       6833           Estado  Rio de Janeiro        33  RJ    None
# 35      13629           Estado  Rio de Janeiro        33  RJ    None
# 37      13483           Estado  Rio de Janeiro        33  RJ    None
# 38       8528           Estado  Rio de Janeiro        33  RJ    None
# 39       9898           Estado  Rio de Janeiro        33  RJ    None
# 40      10606           Estado  Rio de Janeiro        33  RJ    None
# 46      13634           Estado  Rio de Janeiro        33  RJ    None
# ...

# %%
dados_PVL_RJ.loc[dados_PVL_RJ['status'] == 'Arquivado a pedido']
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 20      21660           Estado  Rio de Janeiro        33  RJ
# 27       5640           Estado  Rio de Janeiro        33  RJ
# 48       9042           Estado  Rio de Janeiro        33  RJ
#
#                  num_pvl              status          num_processo  \
# 20  00000.000000/2026-68  Arquivado a pedido  17944.000245/2016-55
# 27                  None  Arquivado a pedido  17944.000160/2013-24
# 48                  None  Arquivado a pedido  17944.000891/2013-70
#
#           data_protocolo                                      tipo_operacao  \
# 20  2016-03-11T03:00:00Z  Operação contratual interna (com garantia da U...
# 27  2013-03-18T03:00:00Z  Operação contratual externa (com garantia da U...
# 48  2013-09-20T03:00:00Z  Operação contratual interna (com garantia da U...
#
#                       finalidade                           tipo_credor  \
# ...

# %%
 dados_PVL_RJ.loc[dados_PVL_RJ['status'] == 'Arquivado por decurso de prazo']
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 43      22594           Estado  Rio de Janeiro        33  RJ
#
#                  num_pvl                          status  \
# 43  00000.000000/2031-89  Arquivado por decurso de prazo
#
#             num_processo        data_protocolo  \
# 43  17944.000657/2016-95  2016-05-12T03:00:00Z
#
#                                         tipo_operacao      finalidade  \
# 43  Operação contratual interna (com garantia da U...  Infraestrutura
#
#                         tipo_credor  \
# 43  Instituição Financeira Nacional
#
#                                                credor moeda        valor  \
# 43  Banco Nacional de Desenvolvimento Econômico e ...  Real  989210440.0
#
#     pvl_assoc_divida  pvl_contradado_credor data_status
# 43                 0                      0  25/10/2016

# %%
# Contando a frequência de cada status
frequencia_status = dados_PVL_RJ['status'].value_counts()

# Selecionando os três status mais frequentes
top_3_status = frequencia_status.head(3)

# Mostrar os três status mais frequentes e suas frequências
print(top_3_status)
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Name: count, dtype: int64

# %% [markdown]
# Ou podemos ir direto no mesmo código:

# %%
# Verificando os status únicos:
print(dados_PVL_RJ['status'].unique())

# Contando a frequência de cada status:
frequencia_status = dados_PVL_RJ['status'].value_counts()

# Selecionando os três status mais frequentes:
top_3_status = frequencia_status.head(3)

# Mostrando os três status mais frequentes e suas frequências:
print(top_3_status)
# Out:
# ['Encaminhado à PGFN com manifestação técnica favorável' 'Deferido'
#  'Arquivado a pedido' 'Arquivado por decurso de prazo']
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Name: count, dtype: int64

# %%
# 3) Código:
# Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().
#Visualizando os dados e tipos:

dados_PVL_RJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
# ...

# %%
#visualizando o formato da data:
dados_PVL_RJ.data_status.head(1)
# Out:
# 0    03/09/2012
# Name: data_status, dtype: object

# %%
# Criando a coluna ano_status e extraindo o ano da coluna 'data_status':

dados_PVL_RJ['ano_status'] = dados_PVL_RJ['data_status'].str.split('/').str[2]

# Visualiza Series com a nova coluna
print(dados_PVL_RJ[['data_status', 'ano_status']])
# Out:
#    data_status ano_status
# 0   03/09/2012       2012
# 1   04/07/2011       2011
# 2   28/09/2009       2009
# 3   13/07/2006       2006
# 4   04/07/2011       2011
# 5   26/02/2016       2016
# 6   25/11/2009       2009
# 7   27/06/2002       2002
# 8   04/10/2012       2012
# 9   04/07/2011       2011
# 10  18/06/2009       2009
# 11  14/09/2012       2012
# 12  06/03/2008       2008
# 13  02/07/2012       2012
# 14  27/12/2013       2013
# 15  27/12/2011       2011
# 16  27/06/2002       2002
# 17  22/05/2009       2009
# 18  04/10/2012       2012
# 19  06/08/2009       2009
# 20  16/05/2016       2016
# 21  06/07/2010       2010
# 22  06/05/2013       2013
# 23  20/11/2012       2012
# 24  29/05/2012       2012
# 25  21/11/2013       2013
# 26  06/05/2013       2013
# 27  29/07/2013       2013
# 28  01/09/2014       2014
# 29  01/09/2014       2014
# 30  20/04/2010       2010
# 31  18/04/2008       2008
# 32  07/07/2009       2009
# 33  11/03/2016       2016
# ...

# %%
#verificando no DataFrame:

dados_PVL_RJ[['data_status', 'ano_status']]
# Out:
#    data_status ano_status
# 0   03/09/2012       2012
# 1   04/07/2011       2011
# 2   28/09/2009       2009
# 3   13/07/2006       2006
# 4   04/07/2011       2011
# 5   26/02/2016       2016
# 6   25/11/2009       2009
# 7   27/06/2002       2002
# 8   04/10/2012       2012
# 9   04/07/2011       2011
# 10  18/06/2009       2009
# 11  14/09/2012       2012
# 12  06/03/2008       2008
# 13  02/07/2012       2012
# 14  27/12/2013       2013
# 15  27/12/2011       2011
# 16  27/06/2002       2002
# 17  22/05/2009       2009
# 18  04/10/2012       2012
# 19  06/08/2009       2009
# 20  16/05/2016       2016
# 21  06/07/2010       2010
# 22  06/05/2013       2013
# 23  20/11/2012       2012
# 24  29/05/2012       2012
# 25  21/11/2013       2013
# 26  06/05/2013       2013
# 27  29/07/2013       2013
# 28  01/09/2014       2014
# 29  01/09/2014       2014
# 30  20/04/2010       2010
# 31  18/04/2008       2008
# 32  07/07/2009       2009
# 33  11/03/2016       2016
# ...

# %%
# 4) Código:

#frequência de cada ano do campo construído no item (3):

# Contando a frequência de cada ano
frequencia_ano = dados_PVL_RJ['ano_status'].value_counts()

# Mostrando a frequência:
print(frequencia_ano)
# Out:
# ano_status
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2002     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: count, dtype: int64

# %%
# Selecionando os três status mais frequentes:
top_3_anos = frequencia_ano.head(3)
top_3_anos
# Out:
# ano_status
# 2012    11
# 2009     9
# 2013     7
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Código:

def dados(uf, tipo_interessado):
    url = f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    response = requests.get(url)
    data_json = response.json()
    if 'items' in data_json:
        dados_df = pd.DataFrame(data_json['items'])
        return dados_df
    else:
        return pd.DataFrame()

# %%
#Testando para SP e Município:

dados_SP_Municipio = dados('SP', 'Município')
pd.DataFrame(dados_SP_Municipio)
# Out:
#       id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 0         20923        Município                Jundiaí   3525904  SP
# 1          9589        Município  Santa Bárbara d'Oeste   3545803  SP
# 2          9149        Município                Jacareí   3524402  SP
# 3          7193        Município               Capivari   3510401  SP
# 4          7195        Município              Pindorama   3538105  SP
# ...         ...              ...                    ...       ...  ..
# 2828      30302        Município     São Caetano do Sul   3548807  SP
# 2829      28149        Município                Ipaussu   3520905  SP
# 2830      29229        Município            Sete Barras   3551801  SP
# 2831      31176        Município               Miracatu   3529906  SP
# 2832      28198        Município                Monções   3531001  SP
#
#                    num_pvl             status          num_processo  \
# ...

# %%
#Testando para RJ e Estado:

dados_RJ_Estado = dados('RJ', 'Estado')
pd.DataFrame(dados_RJ_Estado)
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        7080           Estado  Rio de Janeiro        33  RJ
# 1       10002           Estado  Rio de Janeiro        33  RJ
# 2        8556           Estado  Rio de Janeiro        33  RJ
# 3        9750           Estado  Rio de Janeiro        33  RJ
# 4        7255           Estado  Rio de Janeiro        33  RJ
# 5        5645           Estado  Rio de Janeiro        33  RJ
# 6       10890           Estado  Rio de Janeiro        33  RJ
# 7       21660           Estado  Rio de Janeiro        33  RJ
# 8       13629           Estado  Rio de Janeiro        33  RJ
# 9       13483           Estado  Rio de Janeiro        33  RJ
# 10       6660           Estado  Rio de Janeiro        33  RJ
# 11       5923           Estado  Rio de Janeiro        33  RJ
# 12       9102           Estado  Rio de Janeiro        33  RJ
# 13       7150           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Código:

dados_MG_Estado = dados('MG', 'Estado')
pd.DataFrame(dados_MG_Estado)
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       68204           Estado  Minas Gerais        31  MG
# 1       22380           Estado  Minas Gerais        31  MG
# 2        6917           Estado  Minas Gerais        31  MG
# 3       13549           Estado  Minas Gerais        31  MG
# 4        7023           Estado  Minas Gerais        31  MG
# 5        4926           Estado  Minas Gerais        31  MG
# 6       13641           Estado  Minas Gerais        31  MG
# 7       13441           Estado  Minas Gerais        31  MG
# 8        7280           Estado  Minas Gerais        31  MG
# 9       11696           Estado  Minas Gerais        31  MG
# 10       7435           Estado  Minas Gerais        31  MG
# 11       5828           Estado  Minas Gerais        31  MG
# 12      13447           Estado  Minas Gerais        31  MG
# 13      27063           Estado  Minas Gerais        31  MG
# 14       5582           Estado  Minas Gerais        31  MG
# ...

# %%
# Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?
# Contando a frequência:
frequencia_MG = dados_MG_Estado['status'].value_counts()

# Mostrando a frequência:
print(frequencia_MG)
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado pela STN                                        3
# Arquivado                                                 3
# Em retificação pelo interessado                           1
# Arquivado por decurso de prazo                            1
# Indeferido                                                1
# Name: count, dtype: int64

# %%
#Retornando apenas o status 'Arquivado por decurso de prazo':

Arq_Decurso_Prazo = frequencia_MG.get('Arquivado por decurso de prazo', 0) #.get: contagem do status específico
print(f"Quantidade de solicitações 'Arquivado por decurso de prazo' para MG (Estado): {Arq_Decurso_Prazo}")
# Out:
# Quantidade de solicitações 'Arquivado por decurso de prazo' para MG (Estado): 1

# %% [markdown]
# Podemos, também, deixar tudo num bloco de código:

# %%
# Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?

# Contando a frequência:
frequencia_MG = dados_MG_Estado['status'].value_counts()

# Mostrando a frequência:
print(frequencia_MG)

#Retornando apenas o status 'Arquivado por decurso de prazo':

Arq_Decurso_Prazo = frequencia_MG.get('Arquivado por decurso de prazo', 0) #.get: contagem do status específico
print(f"Quantidade de solicitações 'Arquivado por decurso de prazo' para MG (Estado): {Arq_Decurso_Prazo}")
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado pela STN                                        3
# Arquivado                                                 3
# Em retificação pelo interessado                           1
# Arquivado por decurso de prazo                            1
# Indeferido                                                1
# Name: count, dtype: int64
# Quantidade de solicitações 'Arquivado por decurso de prazo' para MG (Estado): 1

# %%
# 3)  Código: Qual é o município da Bahia com mais solicitações deferidas?:

dados_BA_Municipio = dados('BA', 'Município')
pd.DataFrame(dados_BA_Municipio)
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0         19398        Município                  Itatim   2916856  BA
# 1         11879        Município  Luís Eduardo Magalhães   2919553  BA
# 2          6771        Município             Baianópolis   2902500  BA
# 3          7687        Município   Sebastião Laranjeiras   2930006  BA
# 4          7713        Município              Nordestina   2922656  BA
# ...         ...              ...                     ...       ...  ..
# 1019      10755        Município        Lauro de Freitas   2919207  BA
# 1020      10936        Município      Riachão do Jacuípe   2926301  BA
# 1021      11674        Município  Santo Antônio de Jesus   2928703  BA
# 1022      10504        Município               Cachoeira   2904902  BA
# 1023      10695        Município               Jeremoabo   2918100  BA
#
#                    num_pvl                          status  \
# ...

# %%
# Contando a frequência:
frequencia_BA = dados_BA_Municipio['status'].value_counts()

# Mostrando a frequência:
print(frequencia_BA)

#Retornando apenas o status 'Deferido':

arq_deferido = frequencia_BA.get('Deferido', 0) #.get: contagem do status específico
print(f"Quantidade de solicitações deferidas para BA (Município): {arq_deferido}")
# Out:
# status
# Deferido                                                 446
# Deferido (PVL-IF)                                        201
# Arquivado por decurso de prazo                           136
# Arquivado                                                108
# Regularizado                                              35
# Encaminhado à PGFN com manifestação técnica favorável     31
# Arquivado a pedido                                        22
# Em retificação pelo interessado                           12
# Indeferido                                                10
# Pendente de regularização                                  8
# Em retificação pelo credor                                 5
# Em retificação pelo credor (PVL-IF)                        2
# Assinado pelo interessado (retificação)                    2
# Encaminhado à PGFN (decisão judicial)                      1
# Indeferido (PVL-IF)                                        1
# ...

# %%
# Visualizando os municípios:

mun_BA = dados_BA_Municipio['interessado'].value_counts()
print(mun_BA)
# Out:
# interessado
# Camaçari                  20
# Salvador                  19
# Luís Eduardo Magalhães    19
# Amargosa                  16
# Vitória da Conquista      16
#                           ..
# Quijingue                  1
# Iuiú                       1
# Caturama                   1
# Ibipitanga                 1
# Itagi                      1
# Name: count, Length: 301, dtype: int64

# %%
#retornando o município com maior número de solicitações:

municipio_maior_def = mun_BA.idxmax()# .idxmax() obtem o índice (nome do município) de maior valor.

quantidade_def_maior_mun = mun_BA.max() # .max() obtem o maior valor do município correspondente.

print(f'Município com maior quantidade de solicitações deferidas para BA: {municipio_maior_def} - Quantidade: {quantidade_def_maior_mun}')
# Out:
# Município com maior quantidade de solicitações deferidas para BA: Camaçari - Quantidade: 20

# %%
#Toda a operação no mesmo código:

# Contando a frequência:
frequencia_BA = dados_BA_Municipio['status'].value_counts()

# Mostrando a frequência:
print(frequencia_BA)
print('-------------------')

#mostrando os Municípios:
mun_BA = dados_BA_Municipio['interessado'].value_counts()
print(mun_BA)
print('-------------------')

#Retornando apenas o status 'Deferido':
arq_deferido = frequencia_BA.get('Deferido', 0) #.get: contagem do status específico
print(f"Quantidade de solicitações deferidas para BA (Município): {arq_deferido}")

#retornando o município com maior número de solicitações:
municipio_maior_def = mun_BA.idxmax()# .idxmax() obtem o índice (nome do município) de maior valor.

quantidade_def_maior_mun = mun_BA.max() # .max() obtem o maior valor do município correspondente.

print(f'Município com maior quantidade de solicitações deferidas para BA: {municipio_maior_def} - Quantidade: {quantidade_def_maior_mun}')
# Out:
# status
# Deferido                                                 446
# Deferido (PVL-IF)                                        201
# Arquivado por decurso de prazo                           136
# Arquivado                                                108
# Regularizado                                              35
# Encaminhado à PGFN com manifestação técnica favorável     31
# Arquivado a pedido                                        22
# Em retificação pelo interessado                           12
# Indeferido                                                10
# Pendente de regularização                                  8
# Em retificação pelo credor                                 5
# Em retificação pelo credor (PVL-IF)                        2
# Assinado pelo interessado (retificação)                    2
# Encaminhado à PGFN (decisão judicial)                      1
# Indeferido (PVL-IF)                                        1
# ...

# %%
# 4) Código:

#Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado':

dados_BA_Estado = dados('BA', 'Estado')
pd.DataFrame(dados_BA_Estado)
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        8858           Estado       Bahia        29  BA
# 1       18344           Estado       Bahia        29  BA
# 2       18535           Estado       Bahia        29  BA
# 3       18592           Estado       Bahia        29  BA
# 4        5620           Estado       Bahia        29  BA
# ..        ...              ...         ...       ...  ..
# 81      10860           Estado       Bahia        29  BA
# 82       6610           Estado       Bahia        29  BA
# 83      67368           Estado       Bahia        29  BA
# 84       8115           Estado       Bahia        29  BA
# 85      18539           Estado       Bahia        29  BA
#
#                  num_pvl                                             status  \
# 0                   None  Encaminhado à PGFN com manifestação técnica fa...
# 1                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...

# %%
# 4) Código:

#Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado':

dados_BA_Estado.to_csv('dados_BA_Estado.csv')
